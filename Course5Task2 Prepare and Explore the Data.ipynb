# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#               ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 0             ...                      0          0          0         0
# 1             ...                   3272       3455       3261         0
# 2             ...                  14331      14948      15549      1518
# 3             ...                  28314      28959      29547      2000
# 4             ...                  20940      19146      19131      2000
#
#    PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# ## Feature selection

# %%
credit[['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','PAY_0','PAY_2','PAY_3','PAY_4','BILL_AMT4','BILL_AMT5','BILL_AMT6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6','default payment next month']]
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# 5          50000    1          1         2   37      0      0      0      0
# 6         500000    1          1         2   29      0      0      0      0
# 7         100000    2          2         2   23      0     -1     -1      0
# 8         140000    2          3         1   28      0      0      2      0
# 9          20000    1          3         2   35     -2     -2     -2     -2
# 10        200000    2          3         2   34      0      0      2      0
# ...

# %% [markdown]
# ## Exploratory Data Analysis - Visualizing the Data

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
# Out:
# (array([2.3283e+04, 6.5110e+03, 2.0000e+02, 6.0000e+00]),
#  array([  10000.,  257500.,  505000.,  752500., 1000000.]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['SEX'], bins=4)
# Out:
# (array([11888.,     0.,     0., 18112.]),
#  array([1.  , 1.25, 1.5 , 1.75, 2.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['EDUCATION'], bins=4)
# Out:
# (array([10599., 14030.,  5040.,   331.]),
#  array([0. , 1.5, 3. , 4.5, 6. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['MARRIAGE'], bins=4)
# Out:
# (array([   54., 13659., 15964.,   323.]),
#  array([0.  , 0.75, 1.5 , 2.25, 3.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['AGE'], bins=4)
# Out:
# (array([16809., 10511.,  2570.,   110.]),
#  array([21. , 35.5, 50. , 64.5, 79. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_0'], bins=4)
# Out:
# (array([23182.,  6355.,   424.,    39.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_2'], bins=4)
# Out:
# (array([25562.,  3955.,   450.,    33.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_3'], bins=4)
# Out:
# (array([25787.,  3823.,   337.,    53.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_4'], bins=4)
# Out:
# (array([26490.,  3161.,   284.,    65.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_5'], bins=4)
# Out:
# (array([27032.,  2626.,   279.,    63.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %%
plt.hist(credit['PAY_6'], bins=4)
# Out:
# (array([26921.,  2766.,   246.,    67.]),
#  array([-2. ,  0.5,  3. ,  5.5,  8. ]),
#  <a list of 4 Patch objects>)

# %% [markdown]
# ##  Line Plots

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
x1 = credit['EDUCATION']
y1 = credit['LIMIT_BAL']

# %%
plt.scatter(x1,y1)
plt.show()

# %%
x2 = credit['SEX']
y2 = credit['LIMIT_BAL']

# %%
plt.scatter(x2,y2)
plt.show()

# %% [markdown]
# ## Box Plots

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
B = credit['LIMIT_BAL']
plt.boxplot(B,0,'gD')
plt.show()

# %% [markdown]
# ## Correlation

# %%
credit_iloc =credit.iloc[:,2:25]

# %%
corrMat = credit_iloc.corr()
print(corrMat)
# Out:
#                                  SEX  EDUCATION  MARRIAGE       AGE     PAY_0  \
# SEX                         1.000000   0.014232 -0.031389 -0.090874 -0.057643
# EDUCATION                   0.014232   1.000000 -0.143464  0.175061  0.105364
# MARRIAGE                   -0.031389  -0.143464  1.000000 -0.414170  0.019917
# AGE                        -0.090874   0.175061 -0.414170  1.000000 -0.039447
# PAY_0                      -0.057643   0.105364  0.019917 -0.039447  1.000000
# PAY_2                      -0.070771   0.121566  0.024199 -0.050148  0.672164
# PAY_3                      -0.066096   0.114025  0.032688 -0.053048  0.574245
# PAY_4                      -0.060173   0.108793  0.033122 -0.049722  0.538841
# PAY_5                      -0.055064   0.097520  0.035629 -0.053826  0.509426
# PAY_6                      -0.044008   0.082316  0.034345 -0.048773  0.474553
# BILL_AMT1                  -0.033642   0.023581 -0.023472  0.056239  0.187068
# ...

# %% [markdown]
# ## Covariance

# %%
covMat = credit_iloc.cov()
print(covMat)
# Out:
#                                     SEX    EDUCATION    MARRIAGE  \
# SEX                            0.239247     0.005502   -0.008014
# EDUCATION                      0.005502     0.624651   -0.059184
# MARRIAGE                      -0.008014    -0.059184    0.272452
# AGE                           -0.409726     1.275380   -1.992764
# PAY_0                         -0.031685     0.093584    0.011683
# PAY_2                         -0.041442     0.115025    0.015122
# PAY_3                         -0.038694     0.107861    0.020421
# PAY_4                         -0.034411     0.100528    0.020213
# PAY_5                         -0.030521     0.087340    0.021074
# PAY_6                         -0.024754     0.074816    0.020616
# BILL_AMT1                  -1211.694332  1372.377644 -902.154685
# BILL_AMT2                  -1085.595467  1054.657595 -802.517866
# BILL_AMT3                   -833.207432   712.664124 -901.679085
# ...
